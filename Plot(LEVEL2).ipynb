# %%
import matplotlib.pyplot as plt

a=[0,1,2,3,4]
b=[0,2,4,6,8]

plt.plot(a,b,marker='8',linestyle='dotted',label='Data Points', color='#065c49')
plt.title("Simple Graph With Marker")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
